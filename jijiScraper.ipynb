# %%
from urllib.request import urlopen
from urllib.error import HTTPError
from urllib.error import URLError

from bs4 import BeautifulSoup

try:
    html = urlopen('https://en.wikipedia.org/wiki/Flask_(web_framework)')
except HTTPError as e:
    print("The Server returned an HTTp error")
except URLError as e:
    print("The Server could not be  found!")
else:
    print(html.read())

# %%
from urllib.request import urlopen
from urllib.error import HTTPError
from urllib.error import URLError

from bs4 import BeautifulSoup

try:
    html = urlopen('https://en.wikipedia.org/wiki/Flask_(web_framework)')
except HTTPError as e:
    print("The Server returned an HTTp error")
except URLError as e:
    print("The Server could not be  found!")
else:
    bs1 = BeautifulSoup(html.read(), 'html.parser')
    #print(bs.get_text())

def well_formatted_text(text):
    return text.replace('\n', ' ').replace('\r', '').replace('\t', '')

def get_text(url):
    try:
        html = urlopen(url)
    except HTTPError as e:
        print("The Server returned an HTTp error")
    except URLError as e:
        print("The Server could not be  found!")
    else:
        bs = BeautifulSoup(html.read(), 'html.parser')
        return well_formatted_text(bs.get_text())
    
print(get_text('https://jiji.co.ke/houses-apartments-for-sale'))
# Out:
# The Server returned an HTTp error
# None

# %%
import requests

headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5)'\
           'AppleWebKit 537.36 (KHTML, like Gecko) Chrome',
           'Accept':'text/html,application/xhtml+xml,application/xml;'\
           'q=0.9,image/webp,*/*;q=0.8'}

try:
    html = requests.get('https://jiji.co.ke/houses-apartments-for-sale', headers=headers)
except HTTPError as e:
    print("The Server returned an HTTp error")
except URLError as e:
    print("The Server could not be  found!")
else:
    print(html.text)
# Out:
# <!doctype html>
# <html>
# <head>
#             <link rel="preconnect" href="//assets.jiji.co.ke">
#         <link rel="preconnect" href="//pictures-kenya.jijistatic.com">
#
#
#         <meta property="og:image:type" content="image/jpeg"/>
#     <link rel="image_src" href="https://assets.jiji.co.ke/static/img/preview.jpg"/>
#     <meta property="og:image" content="https://assets.jiji.co.ke/static/img/preview.jpg"/>
#
#     <script nonce="1OUz3c4O9PoaP3qmag4xkxYUJRuCwHyR" type="application/ld+json">
# {
#     "@context": "https://schema.org",
#     "@type": "Organization",
#     "url": "https://jiji.co.ke/?region_subdomain=",
#     "contactPoint": [
#         {
#             "@type": "ContactPoint",
#             "contactType": "customer service",
#             "contactOption": "Jiji Support Team",
#             "availableLanguage" : ["English"],
#             "areaServed": "KE",
#             "email": "support@jiji.co.ke",
#             "url": "https://jiji.co.ke/contacts.html"
# ...

# %%
def get_trap_web(url,headers):
    session = requests.Session()
    req = session.get(url, headers=headers)
    bs = BeautifulSoup(req.text, 'html.parser')
    text = bs.get_text()
    # clean_text = well_formatted_text(text)
    return text

print(get_trap_web('https://en.wikipedia.org/wiki/Blog#Technology', headers))
# Out:
# Blog - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
#
# Toggle sidebar
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Create accountLog in
#
#
#
#
#
# Personal tools
#
#
#
# Create account
# Log in
#
#
#
#
# 			Pages for logged out editors learn more
#
#
#
# TalkContributions
#
#
#
#
#
#
#
#
#
#
#
#
# Navigation
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact usDonate
#
#
#
#
# Contribute
#
#
# HelpLearn to editCommunity portalRecent changesUpload file
#
#
#
#
# Tools
#
#
# What links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationCite this pageWikidata item
#
#
#
#
# Print/export
#
#
# Download as PDFPrintable version
#
#
#
#
# In other projects
#
#
# Wikimedia CommonsWikiquoteWikiversity
#
#
#
#
# Languages
#
# On this Wikipedia the language links are at the top of the page across from the article title. Go to top.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contents
# ...
